# %%
# Demo: load sample transcript and run intent + behavior analyzers
from pathlib import Path

sample = Path('data/sample_transcript.txt').read_text()
print('Sample transcript:', sample)

from backend.intent_classifier import classify_intent
from backend.behavior_analyzer import analyze_transcript

intent = classify_intent(sample)
behavior = analyze_transcript(sample, duration=12.0)

print('Intent:', intent)
print('Behavior:', behavior)

# %% [markdown]
# # Experiments: AI Call Guardian
# This notebook shows exploratory work: STT (Whisper), keyword spotting, lightweight intent classification, behavior features and a hybrid risk engine. Use it to build and test models for the hackathon prototype.
